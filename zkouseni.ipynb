# %%
B =  [[3, 10, 4], [-4, 2, 7], [-4, -8, -3]]
# B =  [[3, -1, 3], [-2, 10, -10], [0, 0, 4]]
B =  [[9, -1, -6], [7, -9, -5], [9, 6, -2]]
B =  [[8, -9, -6], [1, -7, -8], [6, 0, -7]]
B =  [[-8, 0, 6], [5, 2, 1], [-1, 7, -8]]
B =  [[-8, -9, 7], [10, 9, -6], [-8, 4, 10]]


B =  [[-10, 7, 4], [-7, 2, -5], [8, -9, -6]]
B =  [[-10, 7, 4], [-3, 5, 9], [8, -9, -6]]
B =  [[-10, 7, 4], [-3, 5, 9], [-7 , 2 , -5]]


reduced_basis = matrix(B).LLL()

print(reduced_basis)
print(reduced_basis[0].norm().n())
# Out:
# [ 0  0  0]
# [ 7 -2  5]
# [-3  5  9]
# 0.000000000000000
