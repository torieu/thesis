# %%
B =  [[3, 10, 4], [-4, 2, 7], [-4, -8, -3]]
# B =  [[3, -1, 3], [-2, 10, -10], [0, 0, 4]]
B =  [[9, -1, -6], [7, -9, -5], [9, 6, -2]]


reduced_basis = matrix(B).LLL()

print(reduced_basis)
print(reduced_basis[0].norm().n())
# Out:
# [-2 -1  5]
# [ 5 -3  4]
# [ 0 -7 -4]
# 5.47722557505166
