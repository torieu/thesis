# %%
# from generate import *
from closest_vs_minimal import *

# %%
B = [
    [2, 1, 1],
    [1, 3, 1],
    [1, 1, 4]
]

floored = [1, 2, 3]


cube = [1, 2.9, 3.01]

# %%
evaluate_norms_at_cube_efficient(floored, B,0)
# Out:
# [7.0, 10.0, 15.0]
# [[7.0, 10.0, 15.0]]

# %%
evaluate_norms_at_cube(cube_points(cube), B)
# Out:
# [[19.3390796058137, [1, 2, 3]],
#  [22.1133443874960, [1, 3, 3]],
#  [23.3666428910958, [1, 2, 4]],
#  [26.0192236625154, [1, 3, 4]]]

# %%
divna_matice = matrix([[-618412   ,    1   ,    0     ,  0],
[-525693     ,  0    ,   1    ,   0],
[ -49794    ,   0    ,   0   ,    1],
[ 576357   ,    0    ,   0   ,    0]])

divna_matice.LLL()[0].norm().n()
# Out:
# 27.1477439209965
