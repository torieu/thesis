# %%
from random import randint, seed


def shortestVector(matrix):
    """
    Returns the norm of the shortest vector and its index.
    """
    return sorted([(matrix[idx].norm().n(), matrix[idx], idx) for idx in range(matrix.nrows())])[0]

def randomMatrix(dimension, per):
    list = [randint(-per, per) for _ in range(dimension**2)]
    M = matrix(ZZ, dimension, dimension, list)
    while M.rank() != dimension:
        list = [randint(-per, per) for _ in range(dimension**2)]
        M = matrix(ZZ, dimension, dimension, list)
    return M

def gram_matrix(matrix):
    """
    Calculate Gram matrix of given matrix.
    :param matrix: given matrix
    :return: Gram matrix of matrix
    """
    return matrix * matrix.transpose()


def find_real_minimum(G, i, x) -> vector:
    matrixA = matrix(G.nrows() - 1, G.nrows() - 1, 0)
    matrixB = matrix(G.nrows() - 1, 1, 0)
    matrixA[0,0] = 1
    a, b = 0, 0
    for row in range(G.nrows()):
        if row != i:
            matrixA[a] = [G[row, j] for j in range(len(G[row])) if j != i]
            matrixB[b] = sum([x * G[row,j] for j in range(len(G[row])) if j == i])
            a += 1
            b += 1
    #print(matrixA, matrixB)
    # insert indices
    result = (matrixA.solve_right((-1)*matrixB)).list()
    result.insert(i,x)
    return vector(result).n(digits=5)

# %%
def innerComparsion(dimension, perimeter, B, B_red, v_min, x, G,i):
    solutions = find_real_minimum(G, i, x[i])
    for j in range(dimension - 1):  # zbytecny forcyklus???
        difference = x[j] - solutions[j]
        if difference > 1: 
            if all([sol == 0 for sol in solutions]):
                break  
            return into_dict(B, G, x, solutions)
        
def matrix_to_list(A) -> list:
    return [[int(A[row][col]) for col in A.ncols()] for row in A.nrows()]

def vector_to_list():
    pass


def into_dict(B, G, x, solutions) -> dict:
    result = {}
    result["B"] = B
    result["G"] = G
    result["The linear combination given by LLL"] = x
    result["The linear combination suggested by cube"] = solutions
    result["The difference"] = x - vector(solutions)
    result["Shortest vector given by LLL"] = x*B
    return result

# %%
import json

def main():
    output_data = []
    for iteration in range(1000):
        dimension = 3
        perimeter = 10
        B = randomMatrix(dimension, perimeter)
        B_red = B.LLL()
        v_min = shortestVector(B_red)[1]
        x = B.solve_left(v_min) # find linear combination corresponding to shortest vector found by LLL
        G = gram_matrix(B)
        for i in range(G.nrows()):
            data = innerComparsion(dimension, perimeter, B, B_red, v_min, x, G,i) # terrible
            if data != None:
                output_data.append(data)
    print((output_data))
    # print_the_output(output_data)
    into_json(output_data)

def format_data(output_data):
    pass

def into_json(output_data):
    out_file = open("myfile.json", "w") 
    json.dump(output_data, out_file, indent = 6) 
    out_file.close() 


def print_the_output(output_data) -> None:
    for dict in output_data:
        for pair in dict.items():
            print(pair[1], ": ", pair[0])
        print()
    
main()
print("Done")
# Out:
# [{'B': [-7 -4  9]
# [ 3  0 -3]
# [ 7 -9  2], 'G': [146 -48   5]
# [-48  18  15]
# [  5  15 134], 'The linear combination given by LLL': (3, 9, -1), 'The linear combination suggested by cube': (2.5000, 7.5000, -1.0000), 'The difference': (0.50000, 1.5000, 0.00000), 'Shortest vector given by LLL': (-1, -3, -2)}, {'B': [ 9 -9  8]
# [-3  1  0]
# [-8  0  1], 'G': [226 -36 -64]
# [-36  10  24]
# [-64  24  65], 'The linear combination given by LLL': (0, -2, 1), 'The linear combination suggested by cube': (-0.23237, -3.2365, 1.0000), 'The difference': (0.23237, 1.2365, 0.00000), 'Shortest vector given by LLL': (-2, -2, 1)}, {'B': [-6 -7  9]
# [ 0  3 -6]
# [-4  1  5], 'G': [166 -75  62]
# [-75  45 -27]
# [ 62 -27  42], 'The linear combination given by LLL': (0, 1, 1), 'The linear combination suggested by cube': (-0.41463, -0.091057, 1.0000), 'The difference': (0.41463, 1.0911, 0.00000), 'Shortest vector given by LLL': (-4, 4, -1)}, {'B': [ 4  8  4]
# [-7 -9 -8]
# [ 2  5  9], 'G': [  96 -132   84]
# [-132  194 -131]
# [  84 -131  110], 'The linear combination given by LLL': (2, 2, 1), 'The linear combination suggested by cube': (0.83000, 1.2400, 1.0000), 'The difference': (1.1700, 0.76000, 0.00000), 'Shortest vector given by LLL': (-4, 3, 1)}, {'B': [ 6  1 -4]
# [ 4 -9 10]
# [10  0 -4], 'G': [ 53 -25  76]
# [-25 197   0]
# [ 76   0 116], 'The linear combination given by LLL': (9, 1, -6), 'The linear combination suggested by cube': (7.7957, 1.0000, -5.1075), 'The difference': (1.2043, 0.00000, -0.89247), 'Shortest vector given by LLL': (-2, 0, -2)}, {'B': [-1 -3 -3]
# [ 2 -1  2]
# [ 8 -7  8], 'G': [ 19  -5 -11]
# [ -5   9  39]
# [-11  39 177], 'The linear combination given by LLL': (-1, -5, 1), 'The linear combination suggested by cube': (-1.0000, -6.3333, 1.3333), 'The difference': (0.00000, 1.3333, -0.33333), 'Shortest vector given by LLL': (-1, 1, 1)}, {'B': [ 6 -9 10]
# [-1  4 -2]
# [ 0 -6  7], 'G': [217 -62 124]
# [-62  21 -38]
# [124 -38  85], 'The linear combination given by LLL': (0, 2, 1), 'The linear combination suggested by cube': (-0.34783, 0.78261, 1.0000), 'The difference': (0.34783, 1.2174, 0.00000), 'Shortest vector given by LLL': (-2, 2, 3)}]
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In [7], line 34
#      31             print(pair[Integer(1)], ": ", pair[Integer(0)])
#      32         print()
# ---> 34 main()
#      35 print("Done")
#
# Cell In [7], line 19, in main()
#      17 print((output_data))
#      18 # print_the_output(output_data)
# ---> 19 into_json(output_data)
#
# Cell In [7], line 24, in into_json(output_matrix)
#      22 def into_json(output_matrix):
#      23     out_file = open("myfile.json", "w")
# ---> 24     json.dump(output_data, out_file, indent = Integer(6))
#      25     out_file.close()
#
# NameError: name 'output_data' is not defined

# %%
# for single matrix

H = matrix([[5,2,4],[1,3,5],[4,5,2]])
HLLL = H.LLL()
v_min = shortestVector(HLLL)[1]
h = H.solve_left(v_min) # find linear combination corresponding to shortest vector found by LLL
for i in range(H.nrows()):
    variables = [var('y_{}'.format(j)) for j in range(gram_matrix(H).nrows())]
    y = deepcopy(variables)
    y[i] = h[i]
    Y =  matrix(1, H.nrows(), y)
    to_minimize = (Y * gram_matrix(H) * Y.transpose())[0]
    print(to_minimize)
