# %%
dimension = 4
perimeter = 25
sensitivity = 2
jsonfilename = "matrices4x4ver01.json"

# %%
def main() -> None:
    output_data = []
    for iteration in range(10000):
        B = randomMatrix(dimension, perimeter)
        data = abnormality_check(B)
        if data != None:
            output_data.append(abnormality_check(B))
    print_the_output(output_data)
    into_json(format_data(output_data))


def abnormality_check(B) -> dict:
    B_red = B.LLL()
    v_min = shortestVector(B_red)[1]
    x = B.solve_left(v_min) # find linear combination corresponding to shortest vector found by LLL
    G = gram_matrix(B)
    for i in range(G.nrows()):
        data = innerComparsion(dimension, perimeter, B, B_red, v_min, x, G,i) # terrible
        if data != None:
            return data
main()

print("Done")
# Out:
# [ -6  -9   9  25]
# [  0 -21   3  12]
# [-14  -3   1   3]
# [ 14   5  -4 -11] :  B
# [ 823  516  195 -440]
# [ 516  594  102 -249]
# [ 195  102  215 -248]
# [-440 -249 -248  358] :  G
# (-9, 1, -21, -25) :  The linear combination given by LLL
# (-9.8477, 1.0000, -23.398, -27.617) :  The linear combination suggested by cube
# (0.84775, 0.00000, 2.3984, 2.6168) :  The difference
# (-2, -2, 1, -1) :  Shortest vector given by LLL
# (0.028809, -0.25903, 1.4390, -0.60449) :  Shortest vector given by cube
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# [ 13   2  13 -24]
# [  8  -4   4 -12]
# [ 20 -23   9 -19]
# [-23  20   9  20] :  B
# [  918   436   787  -622]
# [  436   240   516  -468]
# [  787   516  1371 -1219]
# [ -622  -468 -1219  1410] :  G
# (1, -4, 1, 0) :  The linear combination given by LLL
# (2.4847, -8.0524, 1.0000, -0.71210) :  The linear combination suggested by cube
# (-1.4847, 4.0524, 0.00000, 0.71210) :  The difference
# (1, -5, 6, 5) :  Shortest vector given by LLL
# (4.2597, -0.063126, 2.6821, 3.7549) :  Shortest vector given by cube
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# [ -1 -11 -18  25]
# [ 11 -11  -5  10]
# [ -3  -3   7   6]
# [-14  -8  24  21] :  B
# [1071  450   60  195]
# [ 450  367   25   24]
# [  60   25  103  360]
# [ 195   24  360 1277] :  G
# (1, -3, 35, -10) :  The linear combination given by LLL
# (1.0000, -2.6298, 28.386, -8.1057) :  The linear combination suggested by cube
# (0.00000, -0.37024, 6.6137, -1.8943) :  The difference
# (1, -3, 2, -5) :  Shortest vector given by LLL
# (-1.6068, -2.3861, -0.68359, -1.1990) :  Shortest vector given by cube
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# [-20  11 -10  -2]
# [-25 -15   3 -17]
# [  6  11  -4  11]
# [ 11 -24  14  -3] :  B
# [ 625  339   19 -618]
# [ 339 1148 -514  178]
# [  19 -514  294 -287]
# [-618  178 -287  902] :  G
# (1, 0, 1, 1) :  The linear combination given by LLL
# (-1.1083, 0.87003, 1.0000, -0.61284) :  The linear combination suggested by cube
# (2.1083, -0.87003, 0.00000, 1.6128) :  The difference
# (-3, -2, 0, 6) :  Shortest vector given by LLL
# (-0.32636, 0.46666, 1.1131, 0.26461) :  Shortest vector given by cube
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# [ 22   6   7   1]
# [ 17  11   0  -5]
# [ 25  16  10   7]
# [-16  20  14  16] :  B
# [ 570  435  723 -118]
# [ 435  435  566 -132]
# [ 723  566 1030  172]
# [-118 -132  172 1108] :  G
# (-1, 1, 0, 0) :  The linear combination given by LLL
# (1.2803, 1.0000, -1.5305, 0.49307) :  The linear combination suggested by cube
# (-2.2803, 0.00000, 1.5305, -0.49307) :  The difference
# (-5, 5, -7, -6) :  Shortest vector given by LLL
# (-0.98640, 4.0546, 0.55960, -6.5443) :  Shortest vector given by cube
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# [ 16  11  22 -13]
# [ -4  -9 -11   4]
# [-24  23 -17  13]
# [-18 -19  20  22] :  B
# [1030 -457 -674 -343]
# [-457  234  128  111]
# [-674  128 1563  -59]
# [-343  111  -59 1569] :  G
# (27, 47, 8, 3) :  The linear combination given by LLL
# (28.176, 49.095, 8.2426, 3.0000) :  The linear combination suggested by cube
# (-1.1757, -2.0950, -0.24265, 0.00000) :  The difference
# (-2, 1, 1, 7) :  Shortest vector given by LLL
# (2.6079, 0.65845, -0.30371, 3.2504) :  Shortest vector given by cube
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# [  0  -9  23 -15]
# [-21  15  -9   9]
# [  7 -12   6  -4]
# [-10  23 -14   9] :  B
# [ 835 -477  306 -664]
# [-477  828 -417  762]
# [ 306 -417  245 -466]
# [-664  762 -466  906] :  G
# (1, 1, 12, 6) :  The linear combination given by LLL
# (0.77734, 1.0000, 9.9150, 4.8284) :  The linear combination suggested by cube
# (0.22266, 0.00000, 2.0850, 1.1716) :  The difference
# (3, 0, 2, 0) :  Shortest vector given by LLL
# (0.12091, 0.077515, 0.77087, 1.1357) :  Shortest vector given by cube
#
# [ -3  16 -19  16]
# [ 10 -15 -21 -15]
# [  6  -5 -25  -5]
# [-17 -11 -22 -13] :  B
# [ 882 -111  297   85]
# [-111  991  735  652]
# [ 297  735  711  568]
# [  85  652  568 1063] :  G
# (15, 27, -35, 1) :  The linear combination given by LLL
# (16.807, 30.109, -38.944, 1.0000) :  The linear combination suggested by cube
# (-1.8068, -3.1087, 3.9445, 0.00000) :  The difference
# (-2, -1, 1, -3) :  Shortest vector given by LLL
# (-0.00024414, 1.0000, 0.00000, -1.0000) :  Shortest vector given by cube
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# [-23  18   1 -18]
# [ -9  -2   9  13]
# [ -5  -6  12  24]
# [ 19  24 -14 -22] :  B
# [1178  -54 -413  377]
# [ -54  335  477 -631]
# [-413  477  781 -935]
# [ 377 -631 -935 1617] :  G
# (-2, 10, -6, 1) :  The linear combination given by LLL
# (-2.5925, 13.141, -8.2000, 1.0000) :  The linear combination suggested by cube
# (0.59248, -3.1414, 2.2000, 0.00000) :  The difference
# (5, 4, 2, 0) :  Shortest vector given by LLL
# (1.3538, 0.25220, 3.2810, -1.2957) :  Shortest vector given by cube
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# [  4   3  25 -10]
# [ 22 -22  -5  12]
# [ -8   8   1   2]
# [ 19 -17   0 -11] :  B
# [ 750 -223   -3  135]
# [-223 1137 -333  660]
# [  -3 -333  133 -310]
# [ 135  660 -310  771] :  G
# (0, 1, 7, 2) :  The linear combination given by LLL
# (-0.18569, 1.0000, 9.2324, 2.8886) :  The linear combination suggested by cube
# (0.18569, 0.00000, -2.2324, -0.88861) :  The difference
# (4, 0, 2, 4) :  Shortest vector given by LLL
# (2.2815, 2.1959, -0.40976, 0.54700) :  Shortest vector given by cube
#
#
#
# [  6  -5   0  -2]
# [ 19  13 -24  21]
# [ 15   5  23   7]
# [-25 -10 -14 -14] :  B
# [  65    7   51  -72]
# [   7 1547  -55 -563]
# [  51  -55  828 -845]
# [ -72 -563 -845 1117] :  G
# (1, 0, 0, 0) :  The linear combination given by LLL
# (1.0000, 1.0015, 2.5698, 2.5133) :  The linear combination suggested by cube
# (0.00000, -1.0015, -2.5698, -2.5133) :  The difference
# (6, -5, 0, -2) :  Shortest vector given by LLL
# (0.74359, -4.2643, -0.11621, 1.8342) :  Shortest vector given by cube
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# [ 15  13  -7   1]
# [-24  -8  11  24]
# [  5 -22  -2 -23]
# [-23 -22   9 -12] :  B
# [ 444 -517 -220 -706]
# [-517 1337 -518  539]
# [-220 -518 1042  627]
# [-706  539  627 1238] :  G
# (12, 3, 1, 5) :  The linear combination given by LLL
# (8.4346, 2.3215, 1.0000, 3.2929) :  The linear combination suggested by cube
# (3.5654, 0.67849, 0.00000, 1.7071) :  The difference
# (-2, 0, -8, 1) :  Shortest vector given by LLL
# (0.067505, -3.3649, -5.8701, 1.6365) :  Shortest vector given by cube
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# [24 10 23 17]
# [-6  0 -8 -5]
# [12 17 -7 19]
# [-2  9 -7  5] :  B
# [1494 -413  620  -34]
# [-413  125 -111   43]
# [ 620 -111  843  273]
# [ -34   43  273  159] :  G
# (-1, -4, 0, 1) :  The linear combination given by LLL
# (-0.050984, -0.86825, -0.40067, 1.0000) :  The linear combination suggested by cube
# (-0.94902, -3.1318, 0.40067, 0.00000) :  The difference
# (-2, -1, 2, 8) :  Shortest vector given by LLL
# (-2.8222, 1.6788, 1.5780, 0.86177) :  Shortest vector given by cube
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# [ -2 -21  -7  11]
# [-12  16  25 -14]
# [  2 -23  19 -19]
# [  3   8   0  -4] :  B
# [ 615 -641  137 -218]
# [-641 1221  349  148]
# [ 137  349 1255 -102]
# [-218  148 -102   89] :  G
# (-26, -8, 1, -49) :  The linear combination given by LLL
# (-23.985, -7.3835, 1.0000, -45.326) :  The linear combination suggested by cube
# (-2.0148, -0.61649, 0.00000, -3.6740) :  The difference
# (3, 3, 1, 3) :  Shortest vector given by LLL
# (2.5945, -0.055176, 2.3088, 1.8357) :  Shortest vector given by cube
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# [ 11   1 -15   8]
# [-22 -19   4  24]
# [ -4 -17  -8  25]
# [-15  -6  22  -7] :  B
# [ 411 -129  259 -557]
# [-129 1437  979  364]
# [ 259  979  994 -189]
# [-557  364 -189  794] :  G
# (-7, -1, 2, -4) :  The linear combination given by LLL
# (-4.5629, -1.0000, 1.7307, -2.3305) :  The linear combination suggested by cube
# (-2.4371, 0.00000, 0.26929, -1.6695) :  The difference
# (-3, 2, -3, -2) :  Shortest vector given by LLL
# (-0.15704, -1.0018, -0.67346, -0.92197) :  Shortest vector given by cube
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# [-20  18 -11 -16]
# [ -5  10  -5 -22]
# [-17   2  -5  24]
# [ 13 -20  12  19] :  B
# [ 1101   687    47 -1056]
# [  687   634  -398  -743]
# [   47  -398   894   135]
# [-1056  -743   135  1074] :  G
# (6, -8, -4, 1) :  The linear combination given by LLL
# (3.2918, -3.6063, -1.9296, 1.0000) :  The linear combination suggested by cube
# (2.7082, -4.3937, -2.0704, 0.00000) :  The difference
# (1, 0, 6, 3) :  Shortest vector given by LLL
# (-2.0010, -0.67065, 3.4700, -0.63855) :  Shortest vector given by cube
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# [  2   9  -6   5]
# [-16  10 -14 -13]
# [  5 -19  17  -3]
# [ -6   9 -17  25] :  B
# [ 146   77 -278  296]
# [  77  721 -469   99]
# [-278 -469  684 -565]
# [ 296   99 -565 1031] :  G
# (70, 22, 46, 3) :  The linear combination given by LLL
# (67.870, 21.472, 44.786, 3.0000) :  The linear combination suggested by cube
# (2.1296, 0.52774, 1.2142, 0.00000) :  The difference
# (0, 3, 3, 1) :  Shortest vector given by LLL
# (-1.8867, 1.6260, 2.5244, 0.85498) :  Shortest vector given by cube
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# [-18   3  13  11]
# [ 17  -5   6  -1]
# [ 24 -15   8   5]
# [ 25 -15  20   3] :  B
# [ 623 -254 -318 -202]
# [-254  351  526  617]
# [-318  526  890 1000]
# [-202  617 1000 1259] :  G
# (1, 3, 1, -2) :  The linear combination given by LLL
# (0.44597, 0.68274, 1.0000, -1.0573) :  The linear combination suggested by cube
# (0.55403, 2.3173, 0.00000, -0.94268) :  The difference
# (7, 3, -1, 7) :  Shortest vector given by LLL
# (1.1462, -1.2160, -3.2524, 6.0509) :  Shortest vector given by cube
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# [-22  21   6 -21]
# [ 10  -5  -4   6]
# [-16   1   3   2]
# [ 18 -21  21  -5] :  B
# [1402 -475  349 -606]
# [-475  177 -165  171]
# [ 349 -165  270 -256]
# [-606  171 -256 1231] :  G
# (5, 17, 5, 1) :  The linear combination given by LLL
# (4.3653, 14.809, 4.3555, 1.0000) :  The linear combination suggested by cube
# (0.63467, 2.1911, 0.64453, 0.00000) :  The difference
# (-2, 4, -2, 2) :  Shortest vector given by LLL
# (0.36475, 0.98267, 1.0226, 0.89270) :  Shortest vector given by cube
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# [ -5  14  -7 -25]
# [ -2 -20   5   5]
# [ 18 -22 -21 -19]
# [ 17 -23 -15  -6] :  B
# [ 895 -430  224 -152]
# [-430  454  204  321]
# [ 224  204 1610 1241]
# [-152  321 1241 1079] :  G
# (-5, -1, 10, -12) :  The linear combination given by LLL
# (-8.3718, -1.0000, 17.373, -20.863) :  The linear combination suggested by cube
# (3.3718, 0.00000, -7.3730, 8.8632) :  The difference
# (3, 6, 0, 2) :  Shortest vector given by LLL
# (1.8984, 0.44238, 1.7178, -0.61255) :  Shortest vector given by cube
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# [ -7  -1  -2  -6]
# [-12 -16  14   2]
# [ 19   1 -13  24]
# [  0  18  -8 -23] :  B
# [  90   60 -252  136]
# [  60  600 -378 -446]
# [-252 -378 1107 -430]
# [ 136 -446 -430  917] :  G
# (-1, 5, 3, 4) :  The linear combination given by LLL
# (-1.0000, 1.7628, 0.93529, 1.4443) :  The linear combination suggested by cube
# (0.00000, 3.2372, 2.0647, 2.5557) :  The difference
# (4, -4, 1, -4) :  Shortest vector given by LLL
# (3.6170, -0.27286, 2.9663, -1.2453) :  Shortest vector given by cube
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# [ 25  12  14  10]
# [-21 -23  -2  -7]
# [ 11  15  23 -22]
# [ 17  -1  18   5] :  B
# [1065 -899  557  715]
# [-899 1023 -468 -405]
# [ 557 -468 1359  476]
# [ 715 -405  476  639] :  G
# (15, 9, 1, -12) :  The linear combination given by LLL
# (12.967, 7.7611, 1.0000, -10.335) :  The linear combination suggested by cube
# (2.0329, 1.2389, 0.00000, -1.6648) :  The difference
# (-7, 0, -1, 5) :  Shortest vector given by LLL
# (-3.5054, 2.4341, 2.9832, 1.6668) :  Shortest vector given by cube
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# [  9  -5 -19  -2]
# [-17 -23  18 -25]
# [ -5   7   7   5]
# [-11 -19 -21 -11] :  B
# [ 471 -330 -223  417]
# [-330 1767  -75  521]
# [-223  -75  148 -280]
# [ 417  521 -280 1044] :  G
# (-3, -1, -3, 1) :  The linear combination given by LLL
# (-4.2934, -1.3193, -5.2458, 1.0000) :  The linear combination suggested by cube
# (1.2934, 0.31934, 2.2458, 0.00000) :  The difference
# (-6, -2, -3, 5) :  Shortest vector given by LLL
# (-0.98291, -3.9089, 0.10614, 4.3411) :  Shortest vector given by cube
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# [-25   8 -12  12]
# [-19   9  -2 -17]
# [ -1   1  -3   9]
# [  7 -23   3  23] :  B
# [ 977  367  177 -119]
# [ 367  735 -119 -737]
# [ 177 -119   92  168]
# [-119 -737  168 1116] :  G
# (-3, 4, 9, 1) :  The linear combination given by LLL
# (-3.5921, 4.5783, 11.007, 1.0000) :  The linear combination suggested by cube
# (0.59205, -0.57834, -2.0067, 0.00000) :  The difference
# (-3, -2, 4, 0) :  Shortest vector given by LLL
# (-1.1938, 0.47534, 3.9279, 1.1238) :  Shortest vector given by cube
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# [-10   2 -12   6]
# [ 25  19  20 -11]
# [ -1 -22   9  -4]
# [  6 -25   5   9] :  B
# [ 284 -518 -166 -116]
# [-518 1507 -219 -324]
# [-166 -219  582  553]
# [-116 -324  553  767] :  G
# (34, 14, 14, 1) :  The linear combination given by LLL
# (40.048, 16.399, 16.643, 1.0000) :  The linear combination suggested by cube
# (-6.0483, -2.3994, -2.6434, 0.00000) :  The difference
# (2, 1, 3, 3) :  Shortest vector given by LLL
# (-1.1410, 0.53027, 2.2002, 2.3223) :  Shortest vector given by cube
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# [ -7 -21   4  15]
# [  4 -12  10  13]
# [-12  14 -22 -13]
# [ -5   7  15 -24] :  B
# [ 731  459 -493 -412]
# [ 459  429 -605 -266]
# [-493 -605  993  140]
# [-412 -266  140  875] :  G
# (-1, 6, 3, 1) :  The linear combination given by LLL
# (-1.0000, 3.8833, 1.8103, 0.42003) :  The linear combination suggested by cube
# (0.00000, 2.1167, 1.1897, 0.57997) :  The difference
# (-10, -2, 5, 0) :  Shortest vector given by LLL
# (-1.2903, 2.6842, 1.3076, 1.8689) :  Shortest vector given by cube
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# [ -6  13 -12   3]
# [-24  19 -17   4]
# [-16  14 -23   8]
# [ 17  18  15 -11] :  B
# [ 358  607  578  -81]
# [ 607 1242 1073 -365]
# [ 578 1073 1045 -453]
# [ -81 -365 -453  959] :  G
# (-26, -2, 19, 6) :  The linear combination given by LLL
# (-29.000, -2.0000, 21.003, 6.7104) :  The linear combination suggested by cube
# (3.0005, 0.00000, -2.0030, -0.71043) :  The difference
# (2, -2, -1, 0) :  Shortest vector given by LLL
# (0.032715, -0.17651, -0.40601, -0.79248) :  Shortest vector given by cube
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# [-21   3  13 -21]
# [ -8  13  14  -4]
# [  2 -25 -14   0]
# [  0  23   2   4] :  B
# [1060  473 -299   11]
# [ 473  445 -537  311]
# [-299 -537  825 -603]
# [  11  311 -603  549] :  G
# (1, -4, -3, -1) :  The linear combination given by LLL
# (0.21535, -1.4817, -1.6173, -1.0000) :  The linear combination suggested by cube
# (0.78465, -2.5183, -1.3827, 0.00000) :  The difference
# (5, 3, -3, -9) :  Shortest vector given by LLL
# (4.0967, -1.1832, 2.6981, -2.5955) :  Shortest vector given by cube
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# [ 17  14 -14   5]
# [  8  16 -18  -2]
# [ -6  16 -19 -14]
# [ -5  16 -14 -11] :  B
# [706 602 318 280]
# [602 648 578 490]
# [318 578 849 706]
# [280 490 706 598] :  G
# (-2, 3, -2, 1) :  The linear combination given by LLL
# (-0.47384, 0.68100, -1.1177, 1.0000) :  The linear combination suggested by cube
# (-1.5262, 2.3190, -0.88229, 0.00000) :  The difference
# (-3, 4, -2, 1) :  Shortest vector given by LLL
# (-0.90098, 2.3789, 1.6122, 0.91678) :  Shortest vector given by cube
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# [ -5   3   1   9]
# [-17  24 -19   7]
# [ -1   9  -6  25]
# [-12 -11  17   1] :  B
# [ 116  201  251   53]
# [ 201 1275  522 -376]
# [ 251  522  743 -164]
# [  53 -376 -164  555] :  G
# (7, -1, -2, -2) :  The linear combination given by LLL
# (9.2497, -1.0000, -2.9597, -2.4354) :  The linear combination suggested by cube
# (-2.2497, 0.00000, 0.95972, 0.43537) :  The difference
# (8, 1, 4, 4) :  Shortest vector given by LLL
# (2.9357, 3.9006, 4.6068, -0.18122) :  Shortest vector given by cube
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# [-18 -12 -11 -10]
# [ 12   7  -4 -20]
# [ 23  16  18  17]
# [  6   4 -15   4] :  B
# [ 689  -56 -974  -31]
# [ -56  609  -24   80]
# [-974  -24 1398    0]
# [ -31   80    0  293] :  G
# (10, 1, 7, 1) :  The linear combination given by LLL
# (12.499, 1.3621, 8.7319, 1.0000) :  The linear combination suggested by cube
# (-2.4995, -0.36213, -1.7319, 0.00000) :  The difference
# (-1, 3, -3, 3) :  Shortest vector given by LLL
# (-1.8118, 3.2515, -0.76880, 0.20459) :  Shortest vector given by cube
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# [ -3   2   7   2]
# [ 24 -14   1 -21]
# [  0 -15   7   3]
# [ -4  -3 -24  10] :  B
# [  66 -135   25 -142]
# [-135 1214  154 -288]
# [  25  154  283  -93]
# [-142 -288  -93  701] :  G
# (-11, -2, 1, -3) :  The linear combination given by LLL
# (-8.5253, -1.6100, 1.0000, -2.2557) :  The linear combination suggested by cube
# (-2.4747, -0.38997, 0.00000, -0.74425) :  The difference
# (-3, 0, 0, -7) :  Shortest vector given by LLL
# (-4.0417, -2.7430, -0.14923, -2.7975) :  Shortest vector given by cube
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# [ 14  21  21 -16]
# [ 16  20 -14   3]
# [ 10  12 -25  10]
# [ -9  13   4 -23] :  B
# [1334  302 -293  599]
# [ 302  861  780   -9]
# [-293  780  969 -264]
# [ 599   -9 -264  795] :  G
# (-12, 27, -25, 1) :  The linear combination given by LLL
# (-10.877, 24.219, -22.512, 1.0000) :  The linear combination suggested by cube
# (-1.1235, 2.7805, -2.4881, 0.00000) :  The difference
# (5, 1, -1, 0) :  Shortest vector given by LLL
# (1.1213, -1.1597, -0.68164, -1.4365) :  Shortest vector given by cube
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# [  4  14 -25  19]
# [  9  10 -10  22]
# [  6   2  -3   3]
# [-19   9  -8  24] :  B
# [1198  844  184  706]
# [ 844  765  170  527]
# [ 184  170   58    0]
# [ 706  527    0 1082] :  G
# (-1, -5, 18, 3) :  The linear combination given by LLL
# (-1.0000, -3.9008, 14.606, 2.5524) :  The linear combination suggested by cube
# (0.00000, -1.0992, 3.3943, 0.44759) :  The difference
# (2, -1, -3, -3) :  Shortest vector given by LLL
# (0.031555, -0.82458, -0.22873, 0.25793) :  Shortest vector given by cube
#
#
#
#
#
#
#
# [ 11 -19   3   2]
# [-11  -1 -15  25]
# [-23  19 -14  23]
# [  4 -23 -15  25] :  B
# [ 495  -97 -610  486]
# [ -97  972 1019  829]
# [-610 1019 1615  256]
# [ 486  829  256 1395] :  G
# (1, -1, 1, 0) :  The linear combination given by LLL
# (1.0000, -6.4453, 4.0092, 2.7461) :  The linear combination suggested by cube
# (0.00000, 5.4453, -3.0092, -2.7461) :  The difference
# (-1, 1, 4, 0) :  Shortest vector given by LLL
# (0.67245, 0.45856, 2.3600, 1.7302) :  Shortest vector given by cube
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# [ -4  -2 -20  17]
# [-20  16  18 -20]
# [-25   7  -2  -4]
# [-13 -11 -23  14] :  B
# [ 709 -652   58  772]
# [-652 1380  656 -610]
# [  58  656  694  238]
# [ 772 -610  238 1015] :  G
# (-1, -1, 1, 0) :  The linear combination given by LLL
# (-1.0000, -2.6191, 3.0864, -1.5372) :  The linear combination suggested by cube
# (0.00000, 1.6191, -2.0864, 1.5372) :  The difference
# (-1, -7, 0, -1) :  Shortest vector given by LLL
# (-0.79535, -1.3919, 2.0381, 1.5162) :  Shortest vector given by cube
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# [-22 -17 -15  14]
# [-22  -6 -15  -9]
# [-15  -7  -6  10]
# [  5  -6  -5  -3] :  B
# [1194  685  679   25]
# [ 685  826  372   28]
# [ 679  372  410  -33]
# [  25   28  -33   95] :  G
# (-26, 1, 44, 22) :  The linear combination given by LLL
# (-23.499, 1.0000, 39.590, 19.641) :  The linear combination suggested by cube
# (-2.5012, 0.00000, 4.4102, 2.3586) :  The difference
# (0, -4, 1, 1) :  Shortest vector given by LLL
# (-0.66797, -1.4979, 1.7354, -1.0087) :  Shortest vector given by cube
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# [ 20 -10 -21  22]
# [-23   3  -2   4]
# [ 12   9 -11 -15]
# [ 13   3  20 -18] :  B
# [1425 -360   51 -586]
# [-360  558 -287 -402]
# [  51 -287  571  233]
# [-586 -402  233  902] :  G
# (5, 9, 1, 7) :  The linear combination given by LLL
# (3.7974, 6.7099, 1.0000, 5.1992) :  The linear combination suggested by cube
# (1.2026, 2.2901, 0.00000, 1.8008) :  The difference
# (-4, 7, 6, 5) :  Shortest vector given by LLL
# (1.2091, 6.7533, -0.18164, 1.7971) :  Shortest vector given by cube
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# [ 24  14  24  -1]
# [-16  20  14 -19]
# [  2   3  13  -6]
# [-22  23 -19  -5] :  B
# [1349  251  408 -657]
# [ 251 1213  324  641]
# [ 408  324  218 -192]
# [-657  641 -192 1399] :  G
# (1, 3, -8, -2) :  The linear combination given by LLL
# (1.0000, 3.8896, -10.020, -2.6876) :  The linear combination suggested by cube
# (0.00000, -0.88962, 2.0196, 0.68764) :  The difference
# (4, 4, 0, 0) :  Shortest vector given by LLL
# (0.85498, -0.081909, -0.73456, -1.3473) :  Shortest vector given by cube
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# [-23   8  22 -10]
# [  8  -4  -9   3]
# [ 16  18  10  15]
# [ -2   1  -8 -21] :  B
# [1177 -444 -154   88]
# [-444  170   11  -11]
# [-154   11  905 -409]
# [  88  -11 -409  510] :  G
# (-126, -328, -17, 1) :  The linear combination given by LLL
# (-118.89, -309.41, -16.018, 1.0000) :  The linear combination suggested by cube
# (-7.1122, -18.594, -0.98203, 0.00000) :  The difference
# (0, -1, 2, 0) :  Shortest vector given by LLL
# (0.88428, -0.80322, 0.94141, -0.60742) :  Shortest vector given by cube
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# [ -5   1  -6   8]
# [  3   9  -3  -4]
# [-22 -15  13   8]
# [ 25   2 -16  13] :  B
# [ 126  -20   81   77]
# [ -20  115 -272   89]
# [  81 -272  942 -684]
# [  77   89 -684 1054] :  G
# (-1, 4, 2, 1) :  The linear combination given by LLL
# (-1.0000, 1.9449, 1.0994, 0.62232) :  The linear combination suggested by cube
# (0.00000, 2.0551, 0.90055, 0.37768) :  The difference
# (-2, 7, 4, 5) :  Shortest vector given by LLL
# (2.2048, 1.2570, 4.5010, 1.1062) :  Shortest vector given by cube
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Done

# %%
mat = matrix([[ -1 ,  9,   1],
           [ -1 ,  6 , -4],
           [  2, -10,   8]])

dictionary = abnormality_check(mat)
for pair in dictionary.items():
    print(pair[1], ": ", pair[0])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In [16], line 6
#       1 mat = matrix([[ -Integer(1) ,  Integer(9),   Integer(1)],
#       2            [ -Integer(1) ,  Integer(6) , -Integer(4)],
#       3            [  Integer(2), -Integer(10),   Integer(8)]])
#       5 dictionary = abnormality_check(mat)
# ----> 6 for pair in dictionary.items():
#       7     print(pair[Integer(1)], ": ", pair[Integer(0)])
#
# AttributeError: 'NoneType' object has no attribute 'items'

# %% [markdown]
# ### batshit cool math

# %%
def innerComparsion(dimension, perimeter, B, B_red, v_min, x, G,i) -> dict:
    solutions = find_real_minimum(G, i, x[i])
    for j in range(dimension - 1):  # zbytecny forcyklus???
        difference = x[j] - solutions[j]
        if abs(difference) > sensitivity: 
            if all([sol == 0 for sol in solutions]):# FIME fuj
                break  
            return into_dict(B, G, x, solutions)
        
def find_real_minimum(G, i, x) -> vector:
    matrixA = matrix(G.nrows() - 1, G.nrows() - 1, 0)
    matrixB = matrix(G.nrows() - 1, 1, 0)
    matrixA[0,0] = 1
    a, b = 0, 0
    for row in range(G.nrows()):
        if row != i:
            matrixA[a] = [G[row, j] for j in range(len(G[row])) if j != i]
            matrixB[b] = sum([x * G[row,j] for j in range(len(G[row])) if j == i])
            a += 1
            b += 1
    # insert indices
    result = (matrixA.solve_right((-1)*matrixB)).list()
    result.insert(i,x)
    return vector(result).n(digits=5) 


#FIXME disgusting code, simplify it
def multiply_B_by_diff(B, diff) -> list:
    B = matrix_to_list(B)
    n = len(B)
    diff = vector_to_list(diff)
    for i in range(n):
        for j in range(n):
            B[i][j] *= diff[i] * diff[j]
    return B

# %%
diff = [1,2,3]
print(mat)
multiply_B_by_diff(mat, diff)
# Out:
# [ -1   9   1]
# [ -1   6  -4]
# [  2 -10   8]
# [[-1, 18, 3], [-2, 24, -24], [6, -60, 72]]

# %% [markdown]
# ### output formatting

# %%
import json

def format_data(output_data):
    for dic in output_data:
        for key, value in dic.items():
            if isinstance(value, sage.matrix.matrix_integer_dense.Matrix_integer_dense):
                dic[key] = matrix_to_list(value)
            else:
            # FIXME here I assume that output_data consits only of matrices and one-line entries (vectors, free modules)
                dic[key] = vector_to_list(value)
    return output_data

def into_json(output_data):
    out_file = open(jsonfilename, "w+") 
    json.dump(output_data, out_file) 
    out_file.close() 


def print_the_output(output_data) -> None:
    for dict in output_data:
        for pair in dict.items():
            print(pair[1], ": ", pair[0])
        print()

# %% [markdown]
# ### uninteresting tools

# %%
from random import randint, seed


def shortestVector(matrix): 
    """
    Returns the norm of the shortest vector and its index.
    """
    return sorted([(matrix[idx].norm().n(), matrix[idx], idx) for idx in range(matrix.nrows())])[0]

def randomMatrix(dimension, per) -> matrix:
    list = [randint(-per, per) for _ in range(dimension**2)]
    M = matrix(ZZ, dimension, dimension, list)
    while M.rank() != dimension:
        list = [randint(-per, per) for _ in range(dimension**2)]
        M = matrix(ZZ, dimension, dimension, list)
    return M

def gram_matrix(matrix) -> matrix:
    """
    Calculate Gram matrix of given matrix.
    :param matrix: given matrix
    :return: Gram matrix of matrix
    """
    return matrix * matrix.transpose()

def matrix_to_list(A) -> list:
    return [[int(A.list()[row * A.ncols() + col]) for col in range(A.ncols())] for row in range(A.nrows())]

def vector_to_list(vector) -> list:
    return [float(num) for num in vector.list()]


def into_dict(B, G, x, solutions) -> dict:
    result = {}
    result["B"] = B
    result["G"] = G
    result["The linear combination given by LLL"] = x
    result["The linear combination suggested by cube"] = solutions
    result["The difference"] = x - vector(solutions)
    result["Shortest vector given by LLL"] = x*B
    result["Shortest vector given by cube"] = vector(solutions)*B
#     result["LLL.norm"] = vector(x*B).norm().n(digits=5)
#     result["cube.norm"] = (vector(solutions)*B).norm().n(digits=5)
    return result
