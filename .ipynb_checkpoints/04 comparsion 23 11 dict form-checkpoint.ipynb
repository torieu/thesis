# %%
from random import randint, seed

def shortestVector(matrix):
    """
    Returns the norm of the shortest vector and its index.
    """
    return sorted([(matrix[idx].norm().n(), matrix[idx], idx) for idx in range(matrix.nrows())])[0]

def randomMatrix(dimension, per):
    list = [randint(-per, per) for _ in range(dimension**2)]
    M = matrix(ZZ, dimension, dimension, list)
    while M.rank() != dimension:
        list = [randint(-per, per) for _ in range(dimension**2)]
        M = matrix(ZZ, dimension, dimension, list)
    return M

def gram_matrix(matrix):
    """
    Calculate Gram matrix of given matrix.
    :param matrix: given matrix
    :return: Gram matrix of matrix
    """
    return matrix * matrix.transpose()

# def find_real_minimum_old(G, i, x):
#     """
#     Returns [y, ...] such that y[i] = x[i] and yGy^T is minimal.
#     """
#     variables = [var('y_{}'.format(j)) for j in range(G.nrows())]
#     y = deepcopy(variables)
#     y[i] = x[i]
#     Y =  matrix(1, G.nrows(), y)
#     to_minimize = (Y * G * Y.transpose())[0]
#     partials =  []
#     eqs = []
#     for variable in variables:
#         derivative = diff(to_minimize, variable)[0]
#         partials.append(derivative)
#         eqs.append(derivative == 0)
#     y.remove(y[i])
#     tmp = list(map(list, solve(eqs, y, solution_dict=True)[0].items())) # jdu blejt 
#     # https://www.geeksforgeeks.org/python-extract-dictionary-values-list-to-list/
#     # now I am missing a single y_i I removed earlier, I want to add it for clarity later
#     # absolutely horrendous code, please bear with me
#     tmp.insert(i, [variables[i], x[i]])
#     # horrendous code -- end
#     return vector([i[1].n(digits=5) for i in tmp])

def find_real_minimum(G, i, x) -> vector:
    """
    Returns [y, ...] such that y[i] = x[i] and yGy^T is minimal.
    """
    matrixA = matrix(G.nrows() - 1, G.nrows() - 1, 0)
    matrixB = matrix(G.nrows() - 1, 1, 0)
    matrixA[0,0] = 1
    a, b = 0, 0
    for row in range(G.nrows()):
        if row != i:
            matrixA[a] = [G[row, j] for j in range(len(G[row])) if j != i]
            matrixB[b] = sum([x * G[row,j] for j in range(len(G[row])) if j == i])
            a += 1
            b += 1
    # insert indices
    result = (matrixA.solve_right((-1)*matrixB)).list()
    result.insert(i,x)
    return vector(result).n(digits=5)

# %%
def innerComparsion(dimension, perimeter, B, B_red, v_min, x, G, i):
    solutions = find_real_minimum(G, i, x[i])
    for j in range(dimension - 1):  # FIXME zbytecny forcyklus???
        difference = x[j] - solutions[j]
        if difference > 1: 
            if all([sol == 0 for sol in solutions]): # FIXME this can be simplified
                break
            return into_dict(B, G, x, solutions)
        
def matrix_to_list(A) -> list:
    # also transforms the numbers into python int
    return [[int(A.list()[row * A.ncols() + col]) for col in range(A.ncols())] for row in range(A.nrows())]

def vector_to_list(vect) -> list:
    # also transforms the numbers into python float
    return [float(num) for num in vect.list()]

def into_dict(B, G, x, solutions) -> dict:
    result = {}
    result["B"] = B
    result["G"] = G
    result["The linear combination given by LLL"] = x
    result["The linear combination suggested by cube"] = solutions
    result["The difference"] = x - vector(solutions)
    result["Shortest vector given by LLL"] = x*B
    return result

# %%
import json

def main():
    output_data = []
    for iteration in range(1000):
        dimension = 4
        perimeter = 20
        B = randomMatrix(dimension, perimeter)
        B_red = B.LLL()
        v_min = shortestVector(B_red)[1]
        x = B.solve_left(v_min) # find linear combination corresponding to shortest vector found by LLL
        G = gram_matrix(B)
        for i in range(G.nrows()):
            data = innerComparsion(dimension, perimeter, B, B_red, v_min, x, G, i) # terrible
            if data != None:
                output_data.append(data)
    print_the_output(output_data)
    into_json(format_data(output_data))

def format_data(output_data):
    for dicti in output_data:
        for item in dicti.items():
            if isinstance(item[1], sage.matrix.matrix_integer_dense.Matrix_integer_dense):
                dicti[item[0]] = matrix_to_list(item[1])
            else: # FIXME here I assume that all other instances in ouput_data are one-line vectors/FreeModules
                dicti[item[0]] = vector_to_list(item[1])
    return output_data

def into_json(output_data):
    out_file = open("myfile.json", "w") 
    json.dump(output_data, out_file) 
    out_file.close() 
    # FIXME https://stackoverflow.com/questions/67346184/adding-a-linebreak-after-every-element-of-python-list-in-json-file


def print_the_output(output_data) -> None:
    for dict in output_data:
        for pair in dict.items():
            print(pair[1], ": ", pair[0])
        print()
    
main()
print("Done")
# Out:
# [-11 -11  -7 -14]
# [-16  -6  -7   3]
# [-13  15 -16 -16]
# [  1  18  -5   6] :  B
# [ 487  249  314 -258]
# [ 249  350  182  -71]
# [ 314  182  906  241]
# [-258  -71  241  386] :  G
# (5, -1, -3, 5) :  The linear combination given by LLL
# (3.7440, -1.0000, -2.0547, 3.6014) :  The linear combination suggested by cube
# (1.2560, 0.00000, -0.94531, 1.3986) :  The difference
# (5, -4, -5, 5) :  Shortest vector given by LLL
#
# [-17  18   5   4]
# [-11  20  -3 -19]
# [ -3  10   8   6]
# [ 12 -18  -8 -15] :  B
# [ 654  456  295 -628]
# [ 456  891   95 -183]
# [ 295   95  209 -370]
# [-628 -183 -370  757] :  G
# (0, 0, 2, 1) :  The linear combination given by LLL
# (0.86774, -0.31199, 0.68736, 1.0000) :  The linear combination suggested by cube
# (-0.86774, 0.31199, 1.3126, 0.00000) :  The difference
# (6, 2, 8, -3) :  Shortest vector given by LLL
#
# [ -4   6   4  -7]
# [-10 -15   2 -12]
# [  0 -17 -12  13]
# [  5 -19  10 -16] :  B
# [ 117   42 -241   18]
# [  42  473   75  447]
# [-241   75  602   -5]
# [  18  447   -5  742] :  G
# (7, -2, 3, 1) :  The linear combination given by LLL
# (5.7371, -1.8566, 2.5364, 1.0000) :  The linear combination suggested by cube
# (1.2629, -0.14337, 0.46363, 0.00000) :  The difference
# (-3, 2, -2, -2) :  Shortest vector given by LLL
#
# [ -7  15  -8  19]
# [ 18  -5  -9   6]
# [-14  16  -2   5]
# [ 20   8  -3  18] :  B
# [ 699  -15  449  346]
# [ -15  466 -284  455]
# [ 449 -284  481  -56]
# [ 346  455  -56  797] :  G
# (-1, 1, 2, 0) :  The linear combination given by LLL
# (-0.47369, 1.0000, 0.99825, -0.29511) :  The linear combination suggested by cube
# (-0.52631, 0.00000, 1.0017, 0.29511) :  The difference
# (-3, 12, -5, -3) :  Shortest vector given by LLL
#
# [  7   0 -12  -2]
# [-14  13  -5 -16]
# [ -4 -20  -9 -20]
# [-16 -13   6 -20] :  B
# [ 197   -6  120 -144]
# [  -6  646  161  345]
# [ 120  161  897  670]
# [-144  345  670  861] :  G
# (9, -2, -6, 7) :  The linear combination given by LLL
# (7.9906, -2.0000, -5.5086, 6.4244) :  The linear combination suggested by cube
# (1.0094, 0.00000, -0.49136, 0.57557) :  The difference
# (3, 3, -2, -6) :  Shortest vector given by LLL
#
# [ 11  18  16  20]
# [ -5 -10   4   5]
# [ -5  20 -19  -9]
# [-12 -19   7  19] :  B
# [1101  -71 -179   18]
# [ -71  166 -296  373]
# [-179 -296  867 -624]
# [  18  373 -624  915] :  G
# (0, -2, 0, 1) :  The linear combination given by LLL
# (-0.26980, -3.0119, -0.36428, 1.0000) :  The linear combination suggested by cube
# (0.26980, 1.0119, 0.36428, 0.00000) :  The difference
# (-2, 1, -1, 9) :  Shortest vector given by LLL
#
# [ -2 -16  18   7]
# [-14  -5   1  15]
# [ 19   4 -18 -18]
# [ 13  -4   9   5] :  B
# [ 633  231 -552  235]
# [ 231  447 -574  -78]
# [-552 -574 1025  -21]
# [ 235  -78  -21  291] :  G
# (-1, 1, 0, 1) :  The linear combination given by LLL
# (-1.0000, -0.092195, -0.57498, 0.74135) :  The linear combination suggested by cube
# (0.00000, 1.0922, 0.57498, 0.25865) :  The difference
# (1, 7, -8, 13) :  Shortest vector given by LLL
#
# [ -5   9   5 -15]
# [ 14   5   2 -11]
# [-17   2  15   9]
# [ -7  -4  10  12] :  B
# [ 356  150   43 -131]
# [ 150  346 -297 -230]
# [  43 -297  599  369]
# [-131 -230  369  309] :  G
# (1, -1, -1, 1) :  The linear combination given by LLL
# (1.6362, -1.0000, -2.2018, 2.5787) :  The linear combination suggested by cube
# (-0.63621, 0.00000, 1.2018, -1.5787) :  The difference
# (-9, -2, -2, -1) :  Shortest vector given by LLL
#
# [-18  -2  14   6]
# [  9   4 -17 -17]
# [ -9 -19  20  -1]
# [ 13  -7   2 -18] :  B
# [ 560 -510  474 -300]
# [-510  675 -480  361]
# [ 474 -480  843   74]
# [-300  361   74  546] :  G
# (1, 1, 0, 0) :  The linear combination given by LLL
# (1.0000, -0.15086, -0.71365, 0.74592) :  The linear combination suggested by cube
# (0.00000, 1.1509, 0.71365, -0.74592) :  The difference
# (-9, 2, -3, -11) :  Shortest vector given by LLL
#
# [-18  -2  14   6]
# [  9   4 -17 -17]
# [ -9 -19  20  -1]
# [ 13  -7   2 -18] :  B
# [ 560 -510  474 -300]
# [-510  675 -480  361]
# [ 474 -480  843   74]
# [-300  361   74  546] :  G
# (1, 1, 0, 0) :  The linear combination given by LLL
# (-0.19636, 1.0000, 0.75631, -0.87156) :  The linear combination suggested by cube
# (1.1964, 0.00000, -0.75631, 0.87156) :  The difference
# (-9, 2, -3, -11) :  Shortest vector given by LLL
#
# [ -4  10   0  -7]
# [-13  -3  -2   9]
# [-19 -11  -4  15]
# [-13  16   6  13] :  B
# [ 165  -41 -139  121]
# [ -41  263  423  226]
# [-139  423  723  242]
# [ 121  226  242  630] :  G
# (2, -10, 6, 1) :  The linear combination given by LLL
# (2.0000, -11.473, 6.7108, 1.1538) :  The linear combination suggested by cube
# (0.00000, 1.4732, -0.71085, -0.15385) :  The difference
# (-5, 0, 2, -1) :  Shortest vector given by LLL
#
# [  8  18   1  14]
# [  5  -1  12 -10]
# [ 16  -7 -17 -14]
# [-13   0 -17  17] :  B
# [ 585 -106 -211  117]
# [-106  270   23 -439]
# [-211   23  790 -157]
# [ 117 -439 -157  747] :  G
# (1, 10, 1, 6) :  The linear combination given by LLL
# (0.88937, 8.5275, 1.0000, 5.0824) :  The linear combination suggested by cube
# (0.11063, 1.4725, 0.00000, 0.91763) :  The difference
# (-4, 1, 2, 2) :  Shortest vector given by LLL
#
# [-18  11   2  16]
# [-13  19  13  13]
# [-16  -9 -19  17]
# [-16 -13 -14  -7] :  B
# [ 705  677  423    5]
# [ 677  868   11 -312]
# [ 423   11  987  520]
# [   5 -312  520  670] :  G
# (-11, 9, 4, 1) :  The linear combination given by LLL
# (-9.6312, 7.8268, 3.5136, 1.0000) :  The linear combination suggested by cube
# (-1.3688, 1.1732, 0.48643, 0.00000) :  The difference
# (1, 1, 5, 2) :  Shortest vector given by LLL
#
# [ 17 -16 -18 -19]
# [-10  15  -8   9]
# [ -1  -3  -1 -16]
# [ -6  12 -11   0] :  B
# [1230 -437  353  -96]
# [-437  470 -171  328]
# [ 353 -171  267  -19]
# [ -96  328  -19  301] :  G
# (0, -1, -1, 1) :  The linear combination given by LLL
# (-0.44409, -2.6462, -1.0000, 2.6788) :  The linear combination suggested by cube
# (0.44409, 1.6462, 0.00000, -1.6788) :  The difference
# (5, 0, -2, 7) :  Shortest vector given by LLL
#
# [  0   7  -5   4]
# [  4 -20   4   4]
# [ -6 -18   7 -18]
# [ -9   1 -18  -2] :  B
# [  90 -144 -233   89]
# [-144  448  292 -136]
# [-233  292  733  -54]
# [  89 -136  -54  410] :  G
# (-8, -1, -2, 1) :  The linear combination given by LLL
# (-9.5847, -1.0000, -2.5442, 1.4138) :  The linear combination suggested by cube
# (1.5847, 0.00000, 0.54419, -0.41379) :  The difference
# (-1, 1, 4, -2) :  Shortest vector given by LLL
#
# [-15 -14  14 -16]
# [  9   1  -8   8]
# [  7   8   2  -2]
# [ -8  -4 -20   2] :  B
# [ 873 -389 -157 -136]
# [-389  210   39  100]
# [-157   39  121 -132]
# [-136  100 -132  484] :  G
# (1, 2, 1, 0) :  The linear combination given by LLL
# (0.46142, 0.52949, 1.0000, 0.29298) :  The linear combination suggested by cube
# (0.53858, 1.4705, 0.00000, -0.29298) :  The difference
# (10, -4, 0, -2) :  Shortest vector given by LLL
#
# [ 16 -20  10   1]
# [ 15 -10   3  -6]
# [ -9  -1  13  16]
# [ -3 -19   9  12] :  B
# [ 757  464   22  434]
# [ 464  370 -182  100]
# [  22 -182  507  355]
# [ 434  100  355  595] :  G
# (-3, 4, 1, 1) :  The linear combination given by LLL
# (-4.1108, 5.2358, 1.0000, 1.5219) :  The linear combination suggested by cube
# (1.1108, -1.2358, 0.00000, -0.52188) :  The difference
# (0, 0, 4, 1) :  Shortest vector given by LLL
#
# [ 15   0 -15   7]
# [ 19  12 -17   3]
# [ -7  15  -9   0]
# [ 15   0 -17  20] :  B
# [499 561  30 620]
# [561 803 200 634]
# [ 30 200 355  48]
# [620 634  48 914] :  G
# (-1, 0, 0, 1) :  The linear combination given by LLL
# (-2.0343, 0.72413, -0.37126, 1.0000) :  The linear combination suggested by cube
# (1.0343, -0.72413, 0.37126, 0.00000) :  The difference
# (0, 0, -2, 13) :  Shortest vector given by LLL
#
# [-19  18  19 -16]
# [ -6  -8 -16  10]
# [ -6   8   2   4]
# [ 20  -2  17  -5] :  B
# [1302 -494  232  -13]
# [-494  456  -20 -426]
# [ 232  -20  120 -122]
# [ -13 -426 -122  718] :  G
# (1, 2, -1, 1) :  The linear combination given by LLL
# (0.027524, -0.38660, -1.0000, -0.39879) :  The linear combination suggested by cube
# (0.97248, 2.3866, 0.00000, 1.3988) :  The difference
# (-5, -8, 2, -5) :  Shortest vector given by LLL
#
# [ -3   5  -6  19]
# [ -4   5   5  11]
# [ 14  -2 -20 -16]
# [ 14   0   4 -12] :  B
# [ 431  216 -236 -294]
# [ 216  187 -342 -168]
# [-236 -342  856  308]
# [-294 -168  308  356] :  G
# (-1, 3, 1, 0) :  The linear combination given by LLL
# (-1.0000, 1.9796, 0.69149, -0.48990) :  The linear combination suggested by cube
# (0.00000, 1.0204, 0.30851, 0.48990) :  The difference
# (5, 8, 1, -2) :  Shortest vector given by LLL
#
# [  1 -16  16  15]
# [ 18   9  19   2]
# [ 10   6  10   6]
# [ -7  17 -15  -9] :  B
# [ 738  208  164 -654]
# [ 208  770  436 -276]
# [ 164  436  272 -172]
# [-654 -276 -172  644] :  G
# (1, 0, 0, 1) :  The linear combination given by LLL
# (1.0000, 0.77597, -1.1964, 1.0286) :  The linear combination suggested by cube
# (0.00000, -0.77597, 1.1964, -0.028561) :  The difference
# (-6, 1, 1, 6) :  Shortest vector given by LLL
#
# [  1 -16  16  15]
# [ 18   9  19   2]
# [ 10   6  10   6]
# [ -7  17 -15  -9] :  B
# [ 738  208  164 -654]
# [ 208  770  436 -276]
# [ 164  436  272 -172]
# [-654 -276 -172  644] :  G
# (1, 0, 0, 1) :  The linear combination given by LLL
# (0.92251, 0.71605, -1.0716, 1.0000) :  The linear combination suggested by cube
# (0.077490, -0.71605, 1.0716, 0.00000) :  The difference
# (-6, 1, 1, 6) :  Shortest vector given by LLL
#
# [ -4   0  -9 -10]
# [-15   5  -2  15]
# [-13   0 -20  -2]
# [-15  -2  10  19] :  B
# [ 197  -72  252 -220]
# [ -72  479  205  480]
# [ 252  205  573  -43]
# [-220  480  -43  690] :  G
# (1, -1, 0, 1) :  The linear combination given by LLL
# (-0.62679, -1.0000, 0.67378, 0.53779) :  The linear combination suggested by cube
# (1.6268, 0.00000, -0.67378, 0.46221) :  The difference
# (-4, -7, 3, -6) :  Shortest vector given by LLL
#
# [-16  17 -18  16]
# [  2  -9   6 -12]
# [ 18  -5   9   4]
# [ 19 -12  18   3] :  B
# [1125 -485 -471 -784]
# [-485  265   87  218]
# [-471   87  446  576]
# [-784  218  576  838] :  G
# (-1, -2, -2, 1) :  The linear combination given by LLL
# (-2.7504, -4.3145, -2.0000, -0.076031) :  The linear combination suggested by cube
# (1.7504, 2.3145, 0.00000, 1.0760) :  The difference
# (-5, -1, 6, 3) :  Shortest vector given by LLL
#
# [  8 -13  -2  14]
# [ 18 -15  -4  10]
# [  7 -15  -4   8]
# [-15 -19  -8   2] :  B
# [433 487 371 171]
# [487 665 447  67]
# [371 447 354 228]
# [171  67 228 654] :  G
# (1, 2, -4, 1) :  The linear combination given by LLL
# (1.0000, 2.5419, -5.0571, 1.2411) :  The linear combination suggested by cube
# (0.00000, -0.54189, 1.0571, -0.24114) :  The difference
# (1, -2, -2, 4) :  Shortest vector given by LLL
#
# [ 10 -15   2 -15]
# [  6  -1  -3   6]
# [-13   7   4 -14]
# [ 14  -8 -10  19] :  B
# [ 554  -21  -17  -45]
# [ -21   82 -181  236]
# [ -17 -181  430 -544]
# [ -45  236 -544  721] :  G
# (0, 2, 1, 0) :  The linear combination given by LLL
# (0.10099, 0.75119, 1.0000, 0.51493) :  The linear combination suggested by cube
# (-0.10099, 1.2488, 0.00000, -0.51493) :  The difference
# (-1, 5, -2, -2) :  Shortest vector given by LLL
#
# [  0  16  -6 -10]
# [  3   3   4 -20]
# [  9 -14  -6  -5]
# [-13  19  14  13] :  B
# [ 392  224 -138   90]
# [ 224  434   61 -186]
# [-138   61  338 -532]
# [  90 -186 -532  895] :  G
# (1, 0, 5, 3) :  The linear combination given by LLL
# (1.0000, -0.17820, 3.4756, 1.9284) :  The linear combination suggested by cube
# (0.00000, 0.17820, 1.5244, 1.0716) :  The difference
# (6, 3, 6, 4) :  Shortest vector given by LLL
#
# [ 12  -8  -4  -9]
# [ 16  -9   6 -11]
# [-16 -18 -19  -1]
# [  2 -20   4  -4] :  B
# [ 305  339   37  204]
# [ 339  494 -197  280]
# [  37 -197  942  256]
# [ 204  280  256  436] :  G
# (3, -3, -1, 1) :  The linear combination given by LLL
# (1.6163, -1.9743, -0.74813, 1.0000) :  The linear combination suggested by cube
# (1.3837, -1.0257, -0.25187, 0.00000) :  The difference
# (6, 1, -7, 3) :  Shortest vector given by LLL
#
# Done

# %%
# for single matrix

H = matrix([[5,2,4],[1,3,5],[4,5,2]])
HLLL = H.LLL()
v_min = shortestVector(HLLL)[1]
v_min
# Out:
# (-1, 3, -2)
